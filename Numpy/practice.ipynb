# %%
import numpy as np
import matplotlib.pyplot as plt

# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("==== Zomato sales analysis ==== ")
print("\n Sales data shape", sales_data.shape)
print("\n Sample data for 1st 3 restau: ", sales_data[:3]) # ALL ROWS FROM 0 TO 3 IE 0:3
# Out:
# ==== Zomato sales analysis ====
#
#  Sales data shape (5, 5)
#
#  Sample data for 1st 3 restau:  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %% [markdown]
# ## Total Sales Per Year

# %%
print("Sales Data Total :: ",Sales_Total_yearwise := np.sum(sales_data[:,1:],axis=0))
print("Company Wise 5 year Total :: ",np.sum(sales_data[:,1:],axis=1))

# Minium Data
print("Minimum Company Wise Data :: ",np.min(sales_data[:,1:],axis=1))

# Maxium Sales Per Year
print("Maximum Sales Per Year :: ",np.max(sales_data[:,1:],axis=0))

# Average Sales Per Rest
print("Avergae Sales Per Restorant :: ",np.average(sales_data[:,1:],axis=0))
print("Avergae Sales Per Restorant :: ",np.mean(sales_data[:,1:],axis=0))

print("Cummulative Sales :: ",cumsum:= np.cumsum(sales_data[:,1:],axis=1))
# Out:
# Sales Data Total ::  [ 810000  945000 1085000 1240000]
# Company Wise 5 year Total ::  [800000 610000 990000 900000 780000]
# Minimum Company Wise Data ::  [150000 120000 200000 180000 160000]
# Maximum Sales Per Year ::  [200000 230000 260000 300000]
# Avergae Sales Per Restorant ::  [162000. 189000. 217000. 248000.]
# Avergae Sales Per Restorant ::  [162000. 189000. 217000. 248000.]
# Cummulative Sales ::  [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %% [markdown]
# ### Plotting

# %%
plt.Figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales across all the restaunts")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
